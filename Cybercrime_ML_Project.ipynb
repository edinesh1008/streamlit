# %% [markdown]
# <a href="https://colab.research.google.com/github/edinesh1008/streamlit/blob/master/Cybercrime_ML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Fraud_Type":[1,2,1,3,2,1,3,2,1,3],
    "Amount":[5000,12000,8000,15000,6000,4000,20000,9000,7000,25000],
    "Latitude":[13.08,12.97,17.38,19.07,28.70,13.06,11.01,9.92,10.79,15.29],
    "Longitude":[80.27,77.59,78.48,72.87,77.10,80.23,76.95,78.11,78.70,74.12],
    "ATM_Location":["Chennai","Bangalore","Hyderabad","Mumbai","Delhi","Tambaram","Coimbatore","Madurai","Trichy","Goa"]
}

df = pd.DataFrame(data)

df.to_csv("fraud_data.csv",index=False)

print("Dataset Created")
# Out:
# Dataset Created

# %%
display(df)
# Out:
#    Fraud_Type  Amount  Latitude  Longitude ATM_Location
# 0           1    5000     13.08      80.27      Chennai
# 1           2   12000     12.97      77.59    Bangalore
# 2           1    8000     17.38      78.48    Hyderabad
# 3           3   15000     19.07      72.87       Mumbai
# 4           2    6000     28.70      77.10        Delhi
# 5           1    4000     13.06      80.23     Tambaram
# 6           3   20000     11.01      76.95   Coimbatore
# 7           2    9000      9.92      78.11      Madurai
# 8           1    7000     10.79      78.70       Trichy
# 9           3   25000     15.29      74.12          Goa

# %%
# !pip install scikit-learn

# %%
import pandas as pd

input_data = pd.DataFrame([{'Fraud_Type': 1, 'Amount': 6000, 'Latitude': 13.08, 'Longitude': 80.27}])
prediction = model.predict(input_data)
print(prediction)
# Out:
# ['Chennai']

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import pickle

# Input features
X = df[['Fraud_Type','Amount','Latitude','Longitude']]

# Output target
y = df['ATM_Location']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# Create model
model = RandomForestClassifier()

# Train model
model.fit(X_train,y_train)

print("Model Training Completed")
# Out:
# Model Training Completed

# %%
pickle.dump(model, open("fraud_model.pkl","wb"))

print("Model Saved")
# Out:
# Model Saved
